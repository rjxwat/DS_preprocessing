# %%
import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\rajpu\AppData\Local\Temp\ipykernel_12916\3010310367.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv('TransformedTrain.csv')

# %%
df
# Out:
#         last_price       mid  opened_position_qty   closed_position_qty  \
# 0        -0.737009 -0.738226             -0.839181            -0.471480
# 1         0.155598  0.158052             -0.839181             1.308879
# 2        -1.067151 -1.065923             -0.839181            -0.471480
# 3        -0.744345 -0.746785             -0.839181            -0.471480
# 4        -0.103625 -0.106063             -0.839181            -0.471480
# ...            ...       ...                   ...                  ...
# 592375   -1.446203 -1.447422              0.539033            -1.361660
# 592376   -0.759018 -0.760235             -0.517478            -0.887052
# 592377    0.901475  0.902708             -0.839181            -0.471480
# 592378   -0.766355 -0.762681             -0.150074            -0.471480
# 592379   -0.018032 -0.019247             -0.499238            -0.910615
#
#         transacted_qty  d_open_interest      bid1      bid2      bid3  \
# ...

# %%
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(24, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f", linewidths=0.5)
plt.title('Pairwise Correlation Heatmap of Features')
plt.show()

# %%
from scipy.stats import spearmanr

# %%
correlation_matrix = df.corr()

# Print the correlation matrix
print("Pearson Correlation Matrix wrt to the target variable")
correlation_matrix.loc[:,'y']
# Out:
# Pearson Correlation Matrix wrt to the target variable
# last_price              0.019276
# mid                     0.018940
# opened_position_qty     0.042177
# closed_position_qty     0.055630
# transacted_qty          0.066684
# d_open_interest        -0.014457
# bid1                    0.018901
# bid2                    0.018984
# bid3                    0.018990
# bid4                    0.018991
# bid5                    0.018989
# ask1                    0.018978
# ask2                    0.019092
# ask3                    0.019109
# ask4                    0.019119
# ask5                    0.019128
# bid1vol                 0.101818
# bid2vol                 0.033954
# bid3vol                 0.009996
# bid4vol                 0.006183
# bid5vol                 0.000167
# ask1vol                -0.158721
# ask2vol                -0.035312
# ask3vol                -0.013279
# ask4vol                -0.011613
# ask5vol                -0.013015
# ...

# %%
df=df.iloc[:,:26]

# %%
from sklearn.decomposition import PCA

# %%
pca =PCA(n_components=10)
df_tranform=pca.fit_transform(df)

# %%
fd=pd.read_csv('TransformedTest.csv')
fd_tranform=pca.transform(fd)

# %%
df_tranform=pd.DataFrame(df_tranform)
fd_tranform=pd.DataFrame(fd_tranform)

# %%
names={0:'pca1',1:'pca2',2:'pca3',3:'pca4',4:'pca5',5:'pca6',6:'pca7',7:'pca8',8:'pca9',9:'pca10'}
df_tranform.rename(columns=names,inplace=True)
fd_tranform.rename(columns=names,inplace=True)

# %%
df_tranform
# Out:
#             pca1      pca2      pca3      pca4      pca5      pca6      pca7  \
# 0       2.526232 -0.910287 -0.067401 -0.931640 -0.219266 -1.238624 -0.598894
# 1      -0.413398  0.923155 -2.056996  1.061374  1.674935 -0.634671 -0.054105
# 2       3.549737 -1.757206 -0.409386 -0.808592 -1.027010 -0.506725  0.462237
# 3       2.713394 -0.253229  0.232452  0.362527  1.101700  2.421539 -0.065672
# 4       0.362571 -0.793495  0.135308 -0.932316  0.563316  1.725565  0.487911
# ...          ...       ...       ...       ...       ...       ...       ...
# 592375  5.290340  0.493838  2.150975  2.813219  0.906850  1.004665 -0.891105
# 592376  2.930537 -0.020041  0.727897  4.180959  2.002804 -1.998931  0.098156
# 592377 -3.196401 -0.493133 -0.600362  0.121327  0.099097 -2.186307  1.441729
# 592378  2.565832 -0.666466 -0.160092  0.119852 -0.889394  1.080822 -0.965496
# 592379  0.087514 -1.165749  0.158434  0.973469 -0.022304  1.296954  0.180780
#
#             pca8      pca9     pca10
# ...

# %%
fd_tranform
# Out:
#              pca1      pca2      pca3      pca4      pca5      pca6      pca7  \
# 0      -12.313375  2.327176 -3.089307  0.369832  0.111785 -1.329034  0.678045
# 1      -12.274551 -1.114238  0.956658  0.429482 -0.224354  1.392413  0.470080
# 2      -12.216127  0.432300  1.911747  1.102800  0.097495 -0.926681  1.658397
# 3      -12.213723  0.270238 -0.634197 -0.237224  1.311280 -2.253483  0.203983
# 4      -12.309207 -1.503592 -0.172155  0.106774  0.064170  0.178571 -0.168791
# ...           ...       ...       ...       ...       ...       ...       ...
# 191854 -12.309265 -1.571763 -0.201555  0.485203  0.053384 -0.064340 -0.005765
# 191855 -12.015988  1.642161  0.026924 -0.627902  2.292398  2.728937  0.274852
# 191856 -12.420502 -1.990622 -0.137832 -0.241708 -0.900695 -0.063987 -0.066648
# 191857 -12.156279  2.572425  1.192932  2.825334 -0.853023  1.284647 -0.889661
# 191858 -12.370149 -0.690865  1.499747  0.170681 -1.161336 -1.019924  0.148106
#
# ...

# %%
correlation_matrix = df_tranform.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
correlation_matrix = fd_tranform.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
df_tranform
# Out:
#             pca1      pca2      pca3      pca4      pca5      pca6      pca7  \
# 0       2.526232 -0.910287 -0.067401 -0.931640 -0.219266 -1.238624 -0.598894
# 1      -0.413398  0.923155 -2.056996  1.061374  1.674935 -0.634671 -0.054105
# 2       3.549737 -1.757206 -0.409386 -0.808592 -1.027010 -0.506725  0.462237
# 3       2.713394 -0.253229  0.232452  0.362527  1.101700  2.421539 -0.065672
# 4       0.362571 -0.793495  0.135308 -0.932316  0.563316  1.725565  0.487911
# ...          ...       ...       ...       ...       ...       ...       ...
# 592375  5.290340  0.493838  2.150975  2.813219  0.906850  1.004665 -0.891105
# 592376  2.930537 -0.020041  0.727897  4.180959  2.002804 -1.998931  0.098156
# 592377 -3.196401 -0.493133 -0.600362  0.121327  0.099097 -2.186307  1.441729
# 592378  2.565832 -0.666466 -0.160092  0.119852 -0.889394  1.080822 -0.965496
# 592379  0.087514 -1.165749  0.158434  0.973469 -0.022304  1.296954  0.180780
#
#             pca8      pca9     pca10
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from sklearn.ensemble import RandomForestClassifier
#
# File c:\Users\rajpu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\__init__.py:87
#      73     # We are not importing the rest of scikit-learn during the build
#      74     # process, as it may not be compiled yet
#      75 else:
#    (...)
#      81     # later is linked to the OpenMP runtime to make it possible to introspect
#      82     # it and importing it first would fail if the OpenMP dll cannot be found.
#      83     from . import (
#      84         __check_build,  # noqa: F401
#      85         _distributor_init,  # noqa: F401
#      86     )
# ---> 87     from .base import clone
#      88     from .utils._show_versions import show_versions
#      90     __all__ = [
#      91         "calibration",
# ...
